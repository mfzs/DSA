# %%
import math
print(math.sqrt(25))
print(math.sqrt(123))
# Out:
# 5.0
# 11.090536506409418

# %%
from math import sqrt
print(sqrt(25))
print(sqrt(123))
# Out:
# 5.0
# 11.090536506409418

# %%
import numpy as np
